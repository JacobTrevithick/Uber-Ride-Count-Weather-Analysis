# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress

uber_raw_df = pd.read_csv('uberCSV/uber-raw-data-apr14.csv')

weather_df = pd.read_csv('Data/NewYorkWeatherData_2014_2015.csv')

# %%
uber_raw_df[['Date', 'Time']] = uber_raw_df['Date/Time'].str.split(" ", expand = True)

uber_df = uber_raw_df[['Date', 'Time', 'Lat', 'Lon']]

fixed_dates = pd.to_datetime(uber_df['Date'])

uber_df['Date'] = fixed_dates

uber_df['Time'] = pd.to_datetime(uber_df['Time'], infer_datetime_format = True)

uber_df['Time'] = uber_df['Time'].astype(str)

uber_df[['WrongDate', 'Time']] = uber_df['Time'].str.split(" ", expand = True)

uber_fixed_df = uber_df[['Date', 'Time', 'Lat', 'Lon']]

uber_fixed_df.head()
# Out:
# C:\Users\marcu\.conda\envs\pythonbeta\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\marcu\.conda\envs\pythonbeta\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\marcu\.conda\envs\pythonbeta\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
uber_fixed_df.groupby(['Date', 'Time']).agg({'Lat': ['count']})
# Out:
#                       Lat
#                     count
# Date       Time
# 2014-04-01 00:00:00     3
#            00:01:00     1
#            00:02:00     3
#            00:03:00     2
#            00:04:00     1
# ...                   ...
# 2014-04-30 23:55:00    13
#            23:56:00    13
#            23:57:00    14
#            23:58:00     5
#            23:59:00     6
#
# [41999 rows x 1 columns]

# %%
weather_df = weather_df[['dt_iso','temp','feels_like']]

weather_df[['Date', 'Time', 'Not sure', 'Timezone']] = weather_df['dt_iso'].str.split(" ", expand = True)

weatherfix_df = weather_df[['Date','Time', 'temp', 'feels_like']]

weatherfix_df.head()

#weather_df = weather_df[['Date', 'Time', 'temp', 'feels_like']]
# Out:
#          Date      Time   temp  feels_like
# 0  2014-01-01  00:00:00  31.95       22.98
# 1  2014-01-01  01:00:00  30.63       21.88
# 2  2014-01-01  02:00:00  30.06       22.44
# 3  2014-01-01  03:00:00  28.51       20.55
# 4  2014-01-01  04:00:00  27.57       20.21

# %%
combined_df = pd.merge(uber_df, weather_df, on = 'Date', how= 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-d94faa48ea2f> in <module>
# ----> 1 combined_df = pd.merge(uber_df, weather_df, on = 'Date', how= 'inner')
#
# ~\.conda\envs\pythonbeta\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\.conda\envs\pythonbeta\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# ...
